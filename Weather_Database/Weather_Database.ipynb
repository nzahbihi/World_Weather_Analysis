# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Import requests library and key.
import requests
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library.
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        #Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data. Found the code for the weather description from:
        # https://stackoverflow.com/questions/25855276/parsing-json-with-python-typeerror-list-indices-must-be-integers-not-str
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                          "Current Description": city_description})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | male
# Processing Record 3 of Set 1 | souillac
# Processing Record 4 of Set 1 | ransang
# Processing Record 5 of Set 1 | qaanaaq
# Processing Record 6 of Set 1 | hami
# Processing Record 7 of Set 1 | saskylakh
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | laguna
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | sao filipe
# Processing Record 12 of Set 1 | tuktoyaktuk
# Processing Record 13 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 1 | haimen
# Processing Record 15 of Set 1 | ostrovnoy
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | zhenlai
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | tabuk
# Processing Record 21 of Set 1 | bairiki
# Processing Record 22 of Set 1 | qasigiannguit
# Processing Record 23 of Set 1 | ribeira grande
# Processing Record 24 of Set 1 | bilibino
# Processing Record 25 of Set 1 | madang
# Processing Record 26 of Set 1 | marshall
# Processing Record 27 of Set 1 | esperance
# Processing Record 28 of Set 1 | pisco
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | avarua
# Processing Record 31 of Set 1 | vostok
# Processing Record 32 of Set 1 | arlit
# Processing Record 33 of Set 1 | nikolskoye
# Processing Record 34 of Set 1 | kodiak
# Processing Record 35 of Set 1 | vaini
# Processing Record 36 of Set 1 | port hardy
# Processing Record 37 of Set 1 | kavaratti
# Processing Record 38 of Set 1 | znamenskoye
# Processing Record 39 of Set 1 | vestmannaeyjar
# Processing Record 40 of Set 1 | puerto ayora
# Processing Record 41 of Set 1 | kavieng
# Processing Record 42 of Set 1 | gheorghe lazar
# Processing Record 43 of Set 1 | saldanha
# Processing Record 44 of Set 1 | srandakan
# Processing Record 45 of Set 1 | lompoc
# Processing Record 46 of Set 1 | murray bridge
# Processing Record 47 of Set 1 | cockburn town
# Processing Record 48 of Set 1 | astakos
# Processing Record 49 of Set 1 | saint george
# Processing Record 50 of Set 1 | sur
# Processing Record 1 of Set 2 | dong xoai
# Processing Record 2 of Set 2 | boa vista
# Processing Record 3 of Set 2 | severo-kurilsk
# Processing Record 4 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 2 | atuona
# Processing Record 6 of Set 2 | lata
# Processing Record 7 of Set 2 | new norfolk
# Processing Record 8 of Set 2 | bluff
# Processing Record 9 of Set 2 | ubauro
# Processing Record 10 of Set 2 | alexandria
# Processing Record 11 of Set 2 | bartica
# Processing Record 12 of Set 2 | castro
# Processing Record 13 of Set 2 | portland
# Processing Record 14 of Set 2 | faanui
# Processing Record 15 of Set 2 | leningradskiy
# Processing Record 16 of Set 2 | hobart
# Processing Record 17 of Set 2 | namibe
# Processing Record 18 of Set 2 | meulaboh
# Processing Record 19 of Set 2 | jacareacanga
# Processing Record 20 of Set 2 | hilo
# Processing Record 21 of Set 2 | tongren
# Processing Record 22 of Set 2 | poum
# Processing Record 23 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 2 | upernavik
# Processing Record 25 of Set 2 | itarema
# Processing Record 26 of Set 2 | yellowknife
# Processing Record 27 of Set 2 | cape town
# Processing Record 28 of Set 2 | mataura
# Processing Record 29 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 2 | ozernovskiy
# Processing Record 31 of Set 2 | najran
# Processing Record 32 of Set 2 | wajima
# Processing Record 33 of Set 2 | bredasdorp
# Processing Record 34 of Set 2 | la seyne-sur-mer
# Processing Record 35 of Set 2 | chokurdakh
# Processing Record 36 of Set 2 | pevek
# Processing Record 37 of Set 2 | georgetown
# Processing Record 38 of Set 2 | east london
# Processing Record 39 of Set 2 | northam
# Processing Record 40 of Set 2 | pangody
# Processing Record 41 of Set 2 | luderitz
# Processing Record 42 of Set 2 | geraldton
# Processing Record 43 of Set 2 | provideniya
# Processing Record 44 of Set 2 | fortuna
# Processing Record 45 of Set 2 | macau
# Processing Record 46 of Set 2 | khatanga
# Processing Record 47 of Set 2 | haibowan
# City not found. Skipping...
# Processing Record 48 of Set 2 | sorland
# Processing Record 49 of Set 2 | chuy
# Processing Record 50 of Set 2 | mailani
# Processing Record 1 of Set 3 | auki
# Processing Record 2 of Set 3 | cherskiy
# Processing Record 3 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 3 | morondava
# Processing Record 5 of Set 3 | kikinda
# Processing Record 6 of Set 3 | valley city
# Processing Record 7 of Set 3 | north platte
# Processing Record 8 of Set 3 | mar del plata
# Processing Record 9 of Set 3 | altamira
# Processing Record 10 of Set 3 | bacuit
# City not found. Skipping...
# Processing Record 11 of Set 3 | newport
# Processing Record 12 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 3 | husavik
# Processing Record 14 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 3 | kaitangata
# Processing Record 16 of Set 3 | butaritari
# Processing Record 17 of Set 3 | carnarvon
# Processing Record 18 of Set 3 | singkawang
# Processing Record 19 of Set 3 | kapaa
# Processing Record 20 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 21 of Set 3 | saravan
# Processing Record 22 of Set 3 | bethel
# Processing Record 23 of Set 3 | yulara
# Processing Record 24 of Set 3 | paso de los toros
# Processing Record 25 of Set 3 | batagay
# Processing Record 26 of Set 3 | zhenjiang
# Processing Record 27 of Set 3 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 28 of Set 3 | cortez
# Processing Record 29 of Set 3 | shingu
# Processing Record 30 of Set 3 | havelock
# Processing Record 31 of Set 3 | tasiilaq
# Processing Record 32 of Set 3 | sinnar
# Processing Record 33 of Set 3 | aginskoye
# Processing Record 34 of Set 3 | fairbanks
# Processing Record 35 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 3 | ballina
# Processing Record 37 of Set 3 | san andres
# Processing Record 38 of Set 3 | hammerfest
# Processing Record 39 of Set 3 | marsh harbour
# Processing Record 40 of Set 3 | kieta
# Processing Record 41 of Set 3 | buenos aires
# Processing Record 42 of Set 3 | dromolaxia
# Processing Record 43 of Set 3 | voisiku
# City not found. Skipping...
# Processing Record 44 of Set 3 | lannion
# Processing Record 45 of Set 3 | ouadda
# Processing Record 46 of Set 3 | arraial do cabo
# Processing Record 47 of Set 3 | tura
# Processing Record 48 of Set 3 | bambous virieux
# Processing Record 49 of Set 3 | iqaluit
# Processing Record 50 of Set 3 | xunchang
# Processing Record 1 of Set 4 | lincoln
# Processing Record 2 of Set 4 | tuatapere
# Processing Record 3 of Set 4 | mount vernon
# Processing Record 4 of Set 4 | cauquenes
# Processing Record 5 of Set 4 | isangel
# Processing Record 6 of Set 4 | verkhniy baskunchak
# Processing Record 7 of Set 4 | dombas
# Processing Record 8 of Set 4 | lebu
# Processing Record 9 of Set 4 | pradopolis
# Processing Record 10 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 11 of Set 4 | norman wells
# Processing Record 12 of Set 4 | karauzyak
# City not found. Skipping...
# Processing Record 13 of Set 4 | roma
# Processing Record 14 of Set 4 | hemnesberget
# Processing Record 15 of Set 4 | zhicheng
# Processing Record 16 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 17 of Set 4 | thompson
# Processing Record 18 of Set 4 | fevralsk
# City not found. Skipping...
# Processing Record 19 of Set 4 | bonavista
# Processing Record 20 of Set 4 | port blair
# Processing Record 21 of Set 4 | bengkulu
# Processing Record 22 of Set 4 | dwarka
# Processing Record 23 of Set 4 | port moresby
# Processing Record 24 of Set 4 | coracora
# Processing Record 25 of Set 4 | torbay
# Processing Record 26 of Set 4 | taguatinga
# Processing Record 27 of Set 4 | malanje
# Processing Record 28 of Set 4 | gigmoto
# Processing Record 29 of Set 4 | mahebourg
# Processing Record 30 of Set 4 | gat
# Processing Record 31 of Set 4 | yeppoon
# Processing Record 32 of Set 4 | kailua
# Processing Record 33 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 4 | penzance
# Processing Record 35 of Set 4 | zeya
# Processing Record 36 of Set 4 | port elizabeth
# Processing Record 37 of Set 4 | saint-augustin
# Processing Record 38 of Set 4 | barrow
# Processing Record 39 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 4 | amahai
# Processing Record 41 of Set 4 | cabedelo
# Processing Record 42 of Set 4 | quatre cocos
# Processing Record 43 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 4 | baherden
# Processing Record 45 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 46 of Set 4 | nishihara
# Processing Record 47 of Set 4 | bykovo
# Processing Record 48 of Set 4 | lavrentiya
# Processing Record 49 of Set 4 | aksu
# Processing Record 50 of Set 4 | santana do livramento
# Processing Record 1 of Set 5 | faya
# Processing Record 2 of Set 5 | sumbawanga
# Processing Record 3 of Set 5 | vestmanna
# Processing Record 4 of Set 5 | umm kaddadah
# Processing Record 5 of Set 5 | loubomo
# Processing Record 6 of Set 5 | waddan
# Processing Record 7 of Set 5 | villa union
# Processing Record 8 of Set 5 | adeje
# Processing Record 9 of Set 5 | tiksi
# Processing Record 10 of Set 5 | pangai
# Processing Record 11 of Set 5 | tukrah
# Processing Record 12 of Set 5 | svetlogorsk
# Processing Record 13 of Set 5 | potosi
# Processing Record 14 of Set 5 | hofn
# Processing Record 15 of Set 5 | berlevag
# Processing Record 16 of Set 5 | tambura
# Processing Record 17 of Set 5 | avera
# Processing Record 18 of Set 5 | plettenberg bay
# Processing Record 19 of Set 5 | broome
# Processing Record 20 of Set 5 | jumla
# Processing Record 21 of Set 5 | mugur-aksy
# Processing Record 22 of Set 5 | hay river
# Processing Record 23 of Set 5 | machilipatnam
# Processing Record 24 of Set 5 | susuman
# Processing Record 25 of Set 5 | bose
# Processing Record 26 of Set 5 | salalah
# Processing Record 27 of Set 5 | kloulklubed
# Processing Record 28 of Set 5 | srednekolymsk
# Processing Record 29 of Set 5 | gorom-gorom
# Processing Record 30 of Set 5 | newark
# Processing Record 31 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 32 of Set 5 | ancud
# Processing Record 33 of Set 5 | mezhdurechensk
# Processing Record 34 of Set 5 | zhuanghe
# Processing Record 35 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 36 of Set 5 | clyde river
# Processing Record 37 of Set 5 | ilheus
# Processing Record 38 of Set 5 | cabo san lucas
# Processing Record 39 of Set 5 | buraydah
# Processing Record 40 of Set 5 | tondi
# Processing Record 41 of Set 5 | kathu
# Processing Record 42 of Set 5 | vardo
# Processing Record 43 of Set 5 | sept-iles
# Processing Record 44 of Set 5 | villanueva
# Processing Record 45 of Set 5 | otane
# Processing Record 46 of Set 5 | vilhena
# Processing Record 47 of Set 5 | ballitoville
# Processing Record 48 of Set 5 | grand gaube
# Processing Record 49 of Set 5 | saint-philippe
# Processing Record 50 of Set 5 | walvis bay
# Processing Record 1 of Set 6 | klaksvik
# Processing Record 2 of Set 6 | bajil
# Processing Record 3 of Set 6 | lukovetskiy
# Processing Record 4 of Set 6 | raga
# Processing Record 5 of Set 6 | longyearbyen
# Processing Record 6 of Set 6 | naze
# Processing Record 7 of Set 6 | jadu
# Processing Record 8 of Set 6 | te anau
# Processing Record 9 of Set 6 | rocha
# Processing Record 10 of Set 6 | batemans bay
# Processing Record 11 of Set 6 | ternate
# Processing Record 12 of Set 6 | jizan
# Processing Record 13 of Set 6 | axim
# Processing Record 14 of Set 6 | harper
# Processing Record 15 of Set 6 | ozu
# Processing Record 16 of Set 6 | carutapera
# Processing Record 17 of Set 6 | vila franca do campo
# Processing Record 18 of Set 6 | xining
# Processing Record 19 of Set 6 | chara
# Processing Record 20 of Set 6 | kondinskoye
# Processing Record 21 of Set 6 | cam pha
# City not found. Skipping...
# Processing Record 22 of Set 6 | ochamchira
# Processing Record 23 of Set 6 | gizo
# Processing Record 24 of Set 6 | coquimbo
# Processing Record 25 of Set 6 | caravelas
# Processing Record 26 of Set 6 | casablanca
# Processing Record 27 of Set 6 | peace river
# Processing Record 28 of Set 6 | rawson
# Processing Record 29 of Set 6 | yumen
# Processing Record 30 of Set 6 | sorong
# Processing Record 31 of Set 6 | hastings
# Processing Record 32 of Set 6 | lishui
# Processing Record 33 of Set 6 | guerrero negro
# Processing Record 34 of Set 6 | deputatskiy
# Processing Record 35 of Set 6 | ahuimanu
# Processing Record 36 of Set 6 | hithadhoo
# Processing Record 37 of Set 6 | vila velha
# Processing Record 38 of Set 6 | rio gallegos
# Processing Record 39 of Set 6 | agirish
# Processing Record 40 of Set 6 | lasa
# Processing Record 41 of Set 6 | chicama
# Processing Record 42 of Set 6 | rio grande
# Processing Record 43 of Set 6 | ust-tsilma
# Processing Record 44 of Set 6 | shimoda
# Processing Record 45 of Set 6 | hobyo
# Processing Record 46 of Set 6 | sola
# Processing Record 47 of Set 6 | flinders
# Processing Record 48 of Set 6 | bull savanna
# Processing Record 49 of Set 6 | marmashen
# Processing Record 50 of Set 6 | zyryanka
# Processing Record 1 of Set 7 | shatrovo
# Processing Record 2 of Set 7 | hasaki
# Processing Record 3 of Set 7 | aklavik
# Processing Record 4 of Set 7 | griffith
# Processing Record 5 of Set 7 | maramba
# Processing Record 6 of Set 7 | sinnamary
# Processing Record 7 of Set 7 | cavalcante
# Processing Record 8 of Set 7 | peniche
# Processing Record 9 of Set 7 | banda aceh
# Processing Record 10 of Set 7 | pringsewu
# Processing Record 11 of Set 7 | mbamba
# Processing Record 12 of Set 7 | la ronge
# Processing Record 13 of Set 7 | nanortalik
# Processing Record 14 of Set 7 | obo
# Processing Record 15 of Set 7 | chokwe
# Processing Record 16 of Set 7 | mollendo
# Processing Record 17 of Set 7 | kanlagay
# Processing Record 18 of Set 7 | khuzhir
# Processing Record 19 of Set 7 | caucaia
# Processing Record 20 of Set 7 | hervey bay
# Processing Record 21 of Set 7 | keti bandar
# Processing Record 22 of Set 7 | sretensk
# Processing Record 23 of Set 7 | san cristobal
# Processing Record 24 of Set 7 | taldom
# Processing Record 25 of Set 7 | porto novo
# Processing Record 26 of Set 7 | kununurra
# Processing Record 27 of Set 7 | mikuni
# Processing Record 28 of Set 7 | airai
# Processing Record 29 of Set 7 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 7 | galle
# Processing Record 31 of Set 7 | itaituba
# Processing Record 32 of Set 7 | okhotsk
# Processing Record 33 of Set 7 | forfar
# Processing Record 34 of Set 7 | san jeronimo
# Processing Record 35 of Set 7 | christchurch
# Processing Record 36 of Set 7 | lima
# Processing Record 37 of Set 7 | krasnousolskiy
# City not found. Skipping...
# Processing Record 38 of Set 7 | jurilovca
# Processing Record 39 of Set 7 | kruisfontein
# Processing Record 40 of Set 7 | benguela
# Processing Record 41 of Set 7 | tigil
# Processing Record 42 of Set 7 | tandalti
# Processing Record 43 of Set 7 | atherton
# Processing Record 44 of Set 7 | acari
# Processing Record 45 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 7 | grindavik
# Processing Record 47 of Set 7 | launceston
# Processing Record 48 of Set 7 | port alfred
# Processing Record 49 of Set 7 | baruun-urt
# Processing Record 50 of Set 7 | abong mbang
# Processing Record 1 of Set 8 | ponta do sol
# Processing Record 2 of Set 8 | bowen
# Processing Record 3 of Set 8 | nome
# Processing Record 4 of Set 8 | snasa
# Processing Record 5 of Set 8 | kokopo
# Processing Record 6 of Set 8 | luang prabang
# Processing Record 7 of Set 8 | madimba
# Processing Record 8 of Set 8 | show low
# Processing Record 9 of Set 8 | dodge city
# Processing Record 10 of Set 8 | dunedin
# Processing Record 11 of Set 8 | pemba
# Processing Record 12 of Set 8 | umarkot
# Processing Record 13 of Set 8 | tricase
# Processing Record 14 of Set 8 | naduvattam
# Processing Record 15 of Set 8 | north bend
# Processing Record 16 of Set 8 | gogrial
# Processing Record 17 of Set 8 | jujuy
# City not found. Skipping...
# Processing Record 18 of Set 8 | tandil
# Processing Record 19 of Set 8 | kushima
# Processing Record 20 of Set 8 | belaya gora
# Processing Record 21 of Set 8 | amapa
# Processing Record 22 of Set 8 | alofi
# Processing Record 23 of Set 8 | eureka
# Processing Record 24 of Set 8 | murgab
# Processing Record 25 of Set 8 | billings
# Processing Record 26 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 8 | omsukchan
# Processing Record 28 of Set 8 | la grande
# Processing Record 29 of Set 8 | victoria
# Processing Record 30 of Set 8 | soller
# Processing Record 31 of Set 8 | dikson
# Processing Record 32 of Set 8 | corinto
# Processing Record 33 of Set 8 | mawlaik
# Processing Record 34 of Set 8 | zhanaozen
# Processing Record 35 of Set 8 | college
# Processing Record 36 of Set 8 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 37 of Set 8 | fort-shevchenko
# Processing Record 38 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 39 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 8 | mogadishu
# Processing Record 41 of Set 8 | cayenne
# Processing Record 42 of Set 8 | panambi
# Processing Record 43 of Set 8 | rive-de-gier
# Processing Record 44 of Set 8 | bathurst
# Processing Record 45 of Set 8 | tabou
# Processing Record 46 of Set 8 | port augusta
# Processing Record 47 of Set 8 | manuk mangkaw
# Processing Record 48 of Set 8 | port-gentil
# Processing Record 49 of Set 8 | tessalit
# Processing Record 50 of Set 8 | antofagasta
# Processing Record 1 of Set 9 | los llanos de aridane
# Processing Record 2 of Set 9 | charters towers
# Processing Record 3 of Set 9 | nizhniy kuranakh
# Processing Record 4 of Set 9 | lorengau
# Processing Record 5 of Set 9 | sitka
# Processing Record 6 of Set 9 | moanda
# Processing Record 7 of Set 9 | la romana
# Processing Record 8 of Set 9 | vao
# Processing Record 9 of Set 9 | luau
# Processing Record 10 of Set 9 | guiratinga
# Processing Record 11 of Set 9 | narsaq
# Processing Record 12 of Set 9 | tiarei
# Processing Record 13 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 9 | talnakh
# Processing Record 15 of Set 9 | biak
# Processing Record 16 of Set 9 | codrington
# Processing Record 17 of Set 9 | tilichiki
# Processing Record 18 of Set 9 | adrar
# Processing Record 19 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 20 of Set 9 | riyadh
# Processing Record 21 of Set 9 | kautokeino
# Processing Record 22 of Set 9 | ola
# Processing Record 23 of Set 9 | buala
# Processing Record 24 of Set 9 | matamoros
# Processing Record 25 of Set 9 | tismana
# Processing Record 26 of Set 9 | hamilton
# Processing Record 27 of Set 9 | sao sebastiao
# Processing Record 28 of Set 9 | pionerskiy
# Processing Record 29 of Set 9 | cidreira
# Processing Record 30 of Set 9 | bhatkal
# Processing Record 31 of Set 9 | baykit
# Processing Record 32 of Set 9 | doha
# Processing Record 33 of Set 9 | nara
# Processing Record 34 of Set 9 | pangnirtung
# Processing Record 35 of Set 9 | leh
# Processing Record 36 of Set 9 | nanakuli
# Processing Record 37 of Set 9 | dingle
# Processing Record 38 of Set 9 | margate
# Processing Record 39 of Set 9 | tazovskiy
# Processing Record 40 of Set 9 | casa nova
# Processing Record 41 of Set 9 | tibiri
# Processing Record 42 of Set 9 | troitskoye
# Processing Record 43 of Set 9 | kaberamaido
# Processing Record 44 of Set 9 | diego de almagro
# Processing Record 45 of Set 9 | mount gambier
# Processing Record 46 of Set 9 | pontianak
# Processing Record 47 of Set 9 | madhoganj
# Processing Record 48 of Set 9 | lagoa
# Processing Record 49 of Set 9 | el angel
# Processing Record 50 of Set 9 | jiujiang
# Processing Record 1 of Set 10 | paraiso
# Processing Record 2 of Set 10 | wilmington
# Processing Record 3 of Set 10 | san ramon de la nueva oran
# Processing Record 4 of Set 10 | kardailovo
# Processing Record 5 of Set 10 | kapit
# Processing Record 6 of Set 10 | bojnurd
# Processing Record 7 of Set 10 | nuevo progreso
# Processing Record 8 of Set 10 | ponta delgada
# Processing Record 9 of Set 10 | anadyr
# Processing Record 10 of Set 10 | vammala
# Processing Record 11 of Set 10 | fare
# Processing Record 12 of Set 10 | saint anthony
# Processing Record 13 of Set 10 | touros
# Processing Record 14 of Set 10 | sivaki
# Processing Record 15 of Set 10 | floriano
# Processing Record 16 of Set 10 | tutoia
# Processing Record 17 of Set 10 | ahome
# Processing Record 18 of Set 10 | birin
# Processing Record 19 of Set 10 | concepcion del uruguay
# Processing Record 20 of Set 10 | tommot
# Processing Record 21 of Set 10 | afrikanda
# Processing Record 22 of Set 10 | santa rosa
# Processing Record 23 of Set 10 | anloga
# Processing Record 24 of Set 10 | korla
# Processing Record 25 of Set 10 | hirara
# Processing Record 26 of Set 10 | palu
# Processing Record 27 of Set 10 | bhadra
# Processing Record 28 of Set 10 | zongolica
# Processing Record 29 of Set 10 | hudson bay
# Processing Record 30 of Set 10 | burns lake
# Processing Record 31 of Set 10 | nouadhibou
# Processing Record 32 of Set 10 | egvekinot
# Processing Record 33 of Set 10 | hearst
# Processing Record 34 of Set 10 | kendari
# Processing Record 35 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 36 of Set 10 | neuquen
# Processing Record 37 of Set 10 | slusovice
# Processing Record 38 of Set 10 | beysehir
# Processing Record 39 of Set 10 | french harbor
# Processing Record 40 of Set 10 | juifang
# City not found. Skipping...
# Processing Record 41 of Set 10 | xai-xai
# Processing Record 42 of Set 10 | katsuura
# Processing Record 43 of Set 10 | takehara
# Processing Record 44 of Set 10 | son la
# Processing Record 45 of Set 10 | bandarbeyla
# Processing Record 46 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 47 of Set 10 | lefka
# Processing Record 48 of Set 10 | guanare
# Processing Record 49 of Set 10 | mergui
# City not found. Skipping...
# Processing Record 50 of Set 10 | tawang
# Processing Record 1 of Set 11 | ormara
# Processing Record 2 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 3 of Set 11 | constitucion
# Processing Record 4 of Set 11 | veshenskaya
# Processing Record 5 of Set 11 | karratha
# Processing Record 6 of Set 11 | manggar
# Processing Record 7 of Set 11 | hvammstangi
# City not found. Skipping...
# Processing Record 8 of Set 11 | houma
# Processing Record 9 of Set 11 | obigarm
# Processing Record 10 of Set 11 | broken hill
# Processing Record 11 of Set 11 | havre-saint-pierre
# Processing Record 12 of Set 11 | winchester
# Processing Record 13 of Set 11 | marzuq
# Processing Record 14 of Set 11 | onguday
# Processing Record 15 of Set 11 | longview
# Processing Record 16 of Set 11 | langsa
# Processing Record 17 of Set 11 | fort nelson
# Processing Record 18 of Set 11 | kualakapuas
# Processing Record 19 of Set 11 | zhuhai
# Processing Record 20 of Set 11 | uige
# Processing Record 21 of Set 11 | nikel
# Processing Record 22 of Set 11 | altoona
# Processing Record 23 of Set 11 | tautira
# Processing Record 24 of Set 11 | dalnegorsk
# Processing Record 25 of Set 11 | goderich
# Processing Record 26 of Set 11 | shache
# Processing Record 27 of Set 11 | chimbote
# Processing Record 28 of Set 11 | oktyabrskiy
# Processing Record 29 of Set 11 | saint-denis
# Processing Record 30 of Set 11 | chernyshevskiy
# Processing Record 31 of Set 11 | sembakung
# Processing Record 32 of Set 11 | amazar
# Processing Record 33 of Set 11 | moss vale
# Processing Record 34 of Set 11 | roquetas de mar
# Processing Record 35 of Set 11 | maldonado
# Processing Record 36 of Set 11 | caborca
# Processing Record 37 of Set 11 | sechura
# Processing Record 38 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 11 | selcuk
# Processing Record 40 of Set 11 | oistins
# Processing Record 41 of Set 11 | nhulunbuy
# Processing Record 42 of Set 11 | calama
# Processing Record 43 of Set 11 | itacoatiara
# Processing Record 44 of Set 11 | aswan
# Processing Record 45 of Set 11 | almaznyy
# Processing Record 46 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 47 of Set 11 | mandera
# Processing Record 48 of Set 11 | sao gabriel da cachoeira
# Processing Record 49 of Set 11 | channel-port aux basques
# Processing Record 50 of Set 11 | vikulovo
# Processing Record 1 of Set 12 | dudinka
# Processing Record 2 of Set 12 | san quintin
# Processing Record 3 of Set 12 | olafsvik
# Processing Record 4 of Set 12 | praia
# Processing Record 5 of Set 12 | tupelo
# Processing Record 6 of Set 12 | rincon
# Processing Record 7 of Set 12 | southbridge
# Processing Record 8 of Set 12 | ust-kuyga
# Processing Record 9 of Set 12 | mulege
# Processing Record 10 of Set 12 | matagami
# Processing Record 11 of Set 12 | altus
# Processing Record 12 of Set 12 | si bun ruang
# Processing Record 13 of Set 12 | marawi
# Processing Record 14 of Set 12 | araceli
# Processing Record 15 of Set 12 | bhaktapur
# Processing Record 16 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 17 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 12 | yakuplu
# Processing Record 19 of Set 12 | salta
# Processing Record 20 of Set 12 | bolshoy uluy
# City not found. Skipping...
# Processing Record 21 of Set 12 | the valley
# Processing Record 22 of Set 12 | manicore
# Processing Record 23 of Set 12 | verkhoyansk
# Processing Record 24 of Set 12 | ylojarvi
# Processing Record 25 of Set 12 | iwaki
# Processing Record 26 of Set 12 | vanavara
# Processing Record 27 of Set 12 | qaqortoq
# Processing Record 28 of Set 12 | asau
# Processing Record 29 of Set 12 | fukue
# Processing Record 30 of Set 12 | iskateley
# Processing Record 31 of Set 12 | santa cruz de tenerife
# Processing Record 32 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 33 of Set 12 | mackay
# Processing Record 34 of Set 12 | belyy yar
# Processing Record 35 of Set 12 | hualmay
# Processing Record 36 of Set 12 | koulikoro
# Processing Record 37 of Set 12 | hauterive
# Processing Record 38 of Set 12 | eydhafushi
# Processing Record 39 of Set 12 | belomorsk
# Processing Record 40 of Set 12 | kaeo
# Processing Record 41 of Set 12 | darapidap
# Processing Record 42 of Set 12 | galgani
# City not found. Skipping...
# Processing Record 43 of Set 12 | hare bay
# Processing Record 44 of Set 12 | praia da vitoria
# Processing Record 45 of Set 12 | mayo
# Processing Record 46 of Set 12 | le vauclin
# Processing Record 47 of Set 12 | kimberley
# Processing Record 48 of Set 12 | deniliquin
# Processing Record 49 of Set 12 | zhanakorgan
# Processing Record 50 of Set 12 | privolzhye
# Processing Record 1 of Set 13 | puerto ayacucho
# Processing Record 2 of Set 13 | sao joao da barra
# Processing Record 3 of Set 13 | kamenka
# Processing Record 4 of Set 13 | sabang
# Processing Record 5 of Set 13 | takoradi
# Processing Record 6 of Set 13 | nicoya
# Processing Record 7 of Set 13 | buluang
# Processing Record 8 of Set 13 | padang
# Processing Record 9 of Set 13 | sobolevo
# Processing Record 10 of Set 13 | marau
# Processing Record 11 of Set 13 | birao
# Processing Record 12 of Set 13 | araouane
# Processing Record 13 of Set 13 | flin flon
# Processing Record 14 of Set 13 | kirakira
# Processing Record 15 of Set 13 | liminangcong
# City not found. Skipping...
# Processing Record 16 of Set 13 | pregradnaya
# Processing Record 17 of Set 13 | chapais
# Processing Record 18 of Set 13 | maniitsoq
# Processing Record 19 of Set 13 | ous
# Processing Record 20 of Set 13 | prince rupert
# Processing Record 21 of Set 13 | petapa
# Processing Record 22 of Set 13 | santa isabel do rio negro
# Processing Record 23 of Set 13 | verkhnevilyuysk
# Processing Record 24 of Set 13 | khandyga
# Processing Record 25 of Set 13 | kabare
# Processing Record 26 of Set 13 | marsaxlokk
# Processing Record 27 of Set 13 | trincomalee
# Processing Record 28 of Set 13 | inuvik
# Processing Record 29 of Set 13 | matara
# Processing Record 30 of Set 13 | los algarrobos
# Processing Record 31 of Set 13 | sakaiminato
# Processing Record 32 of Set 13 | weiser
# Processing Record 33 of Set 13 | gushikawa
# Processing Record 34 of Set 13 | san patricio
# Processing Record 35 of Set 13 | ambon
# Processing Record 36 of Set 13 | lakatoro
# Processing Record 37 of Set 13 | muroto
# Processing Record 38 of Set 13 | vila
# Processing Record 39 of Set 13 | svodin
# Processing Record 40 of Set 13 | rovaniemi
# Processing Record 41 of Set 13 | chipinge
# Processing Record 42 of Set 13 | alyangula
# Processing Record 43 of Set 13 | mount isa
# Processing Record 44 of Set 13 | itupiranga
# Processing Record 45 of Set 13 | mendeleyevsk
# Processing Record 46 of Set 13 | sidi ali
# Processing Record 47 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 48 of Set 13 | rosario oeste
# Processing Record 49 of Set 13 | san lawrenz
# Processing Record 50 of Set 13 | ulaanbaatar
# Processing Record 1 of Set 14 | bismarck
# Processing Record 2 of Set 14 | chalchihuites
# Processing Record 3 of Set 14 | mehamn
# Processing Record 4 of Set 14 | wajir
# Processing Record 5 of Set 14 | saint-gaudens
# Processing Record 6 of Set 14 | bani
# Processing Record 7 of Set 14 | trim
# Processing Record 8 of Set 14 | abha
# Processing Record 9 of Set 14 | ilulissat
# Processing Record 10 of Set 14 | haines junction
# Processing Record 11 of Set 14 | luwingu
# Processing Record 12 of Set 14 | roald
# Processing Record 13 of Set 14 | navolato
# Processing Record 14 of Set 14 | evensk
# Processing Record 15 of Set 14 | iralaya
# Processing Record 16 of Set 14 | hambantota
# Processing Record 17 of Set 14 | namatanai
# Processing Record 18 of Set 14 | camacha
# Processing Record 19 of Set 14 | ratnagiri
# Processing Record 20 of Set 14 | moba
# Processing Record 21 of Set 14 | kismayo
# Processing Record 22 of Set 14 | salinas
# Processing Record 23 of Set 14 | comodoro rivadavia
# Processing Record 24 of Set 14 | palmer
# Processing Record 25 of Set 14 | poronaysk
# Processing Record 26 of Set 14 | bogorodskoye
# Processing Record 27 of Set 14 | sibolga
# Processing Record 28 of Set 14 | nuevo imperial
# Processing Record 29 of Set 14 | moose factory
# Processing Record 30 of Set 14 | stykkisholmur
# Processing Record 31 of Set 14 | shellbrook
# Processing Record 32 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 33 of Set 14 | tucuma
# Processing Record 34 of Set 14 | sardulgarh
# Processing Record 35 of Set 14 | okahandja
# Processing Record 36 of Set 14 | de aar
# Processing Record 37 of Set 14 | urdoma
# Processing Record 38 of Set 14 | yerbogachen
# Processing Record 39 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 40 of Set 14 | oranjemund
# Processing Record 41 of Set 14 | valenca do piaui
# Processing Record 42 of Set 14 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 14 | alugan
# Processing Record 44 of Set 14 | ahipara
# Processing Record 45 of Set 14 | henties bay
# Processing Record 46 of Set 14 | magway
# Processing Record 47 of Set 14 | astana
# Processing Record 48 of Set 14 | tauranga
# Processing Record 49 of Set 14 | bambanglipuro
# Processing Record 50 of Set 14 | smithers
# Processing Record 1 of Set 15 | aksarayskiy
# Processing Record 2 of Set 15 | wanning
# Processing Record 3 of Set 15 | erdaojiang
# Processing Record 4 of Set 15 | chiriqui grande
# Processing Record 5 of Set 15 | adamovka
# Processing Record 6 of Set 15 | berdigestyakh
# Processing Record 7 of Set 15 | naryan-mar
# Processing Record 8 of Set 15 | talaya
# Processing Record 9 of Set 15 | port arthur
# Processing Record 10 of Set 15 | lupiro
# Processing Record 11 of Set 15 | acin
# City not found. Skipping...
# Processing Record 12 of Set 15 | trinidad
# Processing Record 13 of Set 15 | rafraf
# Processing Record 14 of Set 15 | koungou
# Processing Record 15 of Set 15 | aktash
# Processing Record 16 of Set 15 | kurilsk
# Processing Record 17 of Set 15 | tari
# Processing Record 18 of Set 15 | surt
# Processing Record 19 of Set 15 | brokopondo
# Processing Record 20 of Set 15 | jagatsinghapur
# Processing Record 21 of Set 15 | marabba
# Processing Record 22 of Set 15 | maghama
# City not found. Skipping...
# Processing Record 23 of Set 15 | pacific grove
# Processing Record 24 of Set 15 | cesis
# Processing Record 25 of Set 15 | villa oliva
# City not found. Skipping...
# Processing Record 26 of Set 15 | iturama
# Processing Record 27 of Set 15 | parichha
# Processing Record 28 of Set 15 | abalak
# Processing Record 29 of Set 15 | moses lake
# Processing Record 30 of Set 15 | talara
# Processing Record 31 of Set 15 | kishtwar
# Processing Record 32 of Set 15 | verkhnyaya inta
# Processing Record 33 of Set 15 | angoche
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Jamestown  42.0970  -79.2353     69.71        88           0        8.05
# 1       Male   4.1748   73.5089     82.36        77          99       17.81
# 2   Souillac -20.5167   57.5167     71.98        64          40       21.85
# 3    Ransang   8.9603  117.5828     84.24        70         100        2.46
# 4    Qaanaaq  77.4840  -69.3632     40.91        73          15        1.45
# 5       Hami  42.8000   93.4500     92.28        15          99        4.43
# 6  Saskylakh  71.9167  114.0833     44.37        64         100       15.39
# 7   Hermanus -34.4187   19.2345     52.81        78          99        4.94
# 8     Laguna  38.4210 -121.4238     85.01        35           0        8.05
# 9    Ushuaia -54.8000  -68.3000     35.26        80          20        3.44
#
#   Country   Current Description
# 0      US             clear sky
# 1      MV       overcast clouds
# 2      MU            light rain
# 3      PH  heavy intensity rain
# 4      GL            few clouds
# 5      CN       overcast clouds
# 6      RU       overcast clouds
# 7      ZA       overcast clouds
# 8      US             clear sky
# 9      AR            few clouds

# %%
# Reorder the columns.
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df=city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Jamestown      US  42.0970  -79.2353     69.71        88           0
# 1       Male      MV   4.1748   73.5089     82.36        77          99
# 2   Souillac      MU -20.5167   57.5167     71.98        64          40
# 3    Ransang      PH   8.9603  117.5828     84.24        70         100
# 4    Qaanaaq      GL  77.4840  -69.3632     40.91        73          15
# 5       Hami      CN  42.8000   93.4500     92.28        15          99
# 6  Saskylakh      RU  71.9167  114.0833     44.37        64         100
# 7   Hermanus      ZA -34.4187   19.2345     52.81        78          99
# 8     Laguna      US  38.4210 -121.4238     85.01        35           0
# 9    Ushuaia      AR -54.8000  -68.3000     35.26        80          20
#
#    Wind Speed   Current Description
# 0        8.05             clear sky
# 1       17.81       overcast clouds
# 2       21.85            light rain
# 3        2.46  heavy intensity rain
# 4        1.45            few clouds
# 5        4.43       overcast clouds
# 6       15.39       overcast clouds
# 7        4.94       overcast clouds
# 8        8.05             clear sky
# 9        3.44            few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
